# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-search-results
#   Downloading google_search_results-2.4.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from google-search-results) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->google-search-results) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->google-search-results) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->google-search-results) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->google-search-results) (1.24.3)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25788 sha256=73d8ec50f4271251a906ba40c15271b99edcbdf76ec5cc975dd246276f5c1d8d
#   Stored in directory: /root/.cache/pip/wheels/ea/58/9e/3d89ebff948ef9ce0a6e056a8279c1f93c76993387766f8387
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import ast

# %%
from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl
import pandas as pd
import os, json

# %% [markdown]
# # Scrapping

# %%
def scrape_google_scholar_author(scl_id):

    params = {
        "api_key": "3abb3f7b2d2f9533935fee8f638da3d8eb44f3afb08bcf85097547bac3a36ad9",      # SerpApi API key
        "engine": "google_scholar_author",    # author results search engine
        "author_id":scl_id,          # search query
        "hl": "en"                            # language
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    # print(results)

    author_results_data = {
        "author_data": {},
        "author_articles": []
    }

    author_results_data["author_data"]["name"] = results.get("author").get("name")
    author_results_data["author_data"]["email"] = results.get("author").get("email")
    author_results_data["author_data"]["website"] = results.get("author").get("website")
    author_results_data["author_data"]["interests"] = results.get("author").get("interests")
    author_results_data["author_data"]["affiliations"] = results.get("author").get("affiliations")
    author_results_data["author_data"]["thumbnail"] = results.get("author").get("thumbnail")

    author_results_data["author_data"]["cited_by_table"] = results.get("cited_by", {}).get("table")
    author_results_data["author_data"]["cited_by_graph"] = results.get("cited_by", {}).get("graph")

    author_results_data["author_data"]["public_access_link"] = results.get("public_access", {}).get("link")
    author_results_data["author_data"]["public_access_available"] = results.get("public_access", {}).get("available")
    author_results_data["author_data"]["public_access_not_available"] = results.get("public_access", {}).get("not_available")
    author_results_data["author_data"]["co_authors"] = results.get("co_authors")

    # extracting all author articles
    while True:
        results = search.get_dict()

        for article in results.get("articles", []):

            print(f"Extracting article: {article.get('title')} ")

            author_results_data["author_articles"].append({
                "article_title": article.get("title"), #title
                "article_link": article.get("link"),
                "article_year": article.get("citation_id"),
                "article_citation_id": article.get("authors"),
                "article_authors": article.get("publication"),
                "article_publication": article.get("cited_by", {}).get("value"),
                "article_cited_by_value": article.get("cited_by", {}).get("link"),
                "article_cited_by_link": article.get("cited_by", {}).get("cites_id"),
                "article_cited_by_cites_id": article.get("year")
            })

        if "next" in results.get("serpapi_pagination", []):
            search.params_dict.update(dict(parse_qsl(urlsplit(results.get("serpapi_pagination").get("next")).query)))
        else:
            break

    #print(json.dumps(author_results_data, indent=2, ensure_ascii=False))
    #print(f"Done. Extracted {len(author_results_data['author_articles'])-1} articles.") # counts extra empty line, that's why -1.

    # masatoshi_nei_author_articles.csv
    pd.DataFrame(data=author_results_data["author_articles"]).to_csv("/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/"+author_results_data['author_data']['name'].lower()+"_author_articles.csv")
    #df = pd.DataFrame(data=author_results_data["author_articles"])
    author_results_data["author_data"]['link'] = '/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/'+author_results_data['author_data']['name'].lower()+'_author_articles.csv'
    return author_results_data['author_data']

# %%
df = pd.read_csv('/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/nlp_hathon_cse.csv')
df.head()
# Out:
#    Unnamed: 0                                          Expertise  \
# 0           0  ['Computer Science Information Systems', 'Algo...
# 1           1  ['Computer Science Artificial Intelligence  ',...
# 2           2  ['Computer Science Information Systems ', 'Dat...
# 3           3  ['Computer Science Artificial Intelligence', '...
# 4           4  ['Computer Science Artificial Intelligence', '...
#
#                           Name Google_schloe_id
# 0              Dr Venkatesan R     sox193AAAAAJ
# 1        Dr G. Sudha Sadasivam     1TCSp8sAAAAJ
# 2    Dr Karpagam Manavalan G R     MsVSOuwAAAAJ
# 3             Dr Jayashree L S     mmNPmLoAAAAJ
# 4       Dr Arulanand Natarajan     cLqiFpwAAAAJ

# %%
author_data = []
for i in df['Google_schloe_id']:
  try:
    author_data.append(scrape_google_scholar_author(i))
  except:
    author_data.append({})
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: A SURVEY ON AUTOMATIC TEST CASE GENERATION
# Extracting article: A survey on applications of neural networks and evolutionary techniques in web caching
# Extracting article: A Fuzzy Based Energy-aware Clustering Architecture for Cooperative Communication in WSN
# Extracting article: A Cognitive Multi-hop Clustering Approach for Wireless Sensor Networks
# Extracting article: A scalable method for link prediction in large real world networks
# Extracting article: A New Image Encryption Method Based on Knight’s Travel Path and True Random Number
# Extracting article: Meta-heuristic approaches for minimizing error in localization of wireless sensor networks
# Extracting article: A novel image encryption using calligraphy based scan method and random number
# Extracting article: A novel approach for image encryption using dynamic SCAN pattern
# Extracting article: A novel image encryption approach using matrix reordering
# Extracting article: A survey on biometrics based cryptographic key generation schemes
# Extracting article: Cost-Sensitive Radial Basis Function Neural Network Classifier for Software Defect Prediction
# Extracting article: Image encryption based on pixel shuffling and random key stream
# Extracting article: An energy balanced geo-cluster head set based multi-hop routing for wireless sensor networks
# Extracting article: An Analysis of software-defined routing approach for wireless sensor networks
# Extracting article: Secure biometric key generation scheme for cryptography using combined biometric features of fingerprint and iris
# Extracting article: Hyperparameters Tuning of Ensemble Model for Software Effort Estimation
# Extracting article: An adaptive distributed power efficient clustering algorithm for wireless sensor networks
# Extracting article: Energy efficient hierarchical clustering for sensor networks
# Extracting article: Semantic Web Prefetching Scheme using Naïve Bayes Classifier.
# https://serpapi.com/search
# Extracting article: Fuzzified dynamic power control algorithm for wireless sensor networks
# Extracting article: Error minimization in localization of wireless sensor networks using fish swarm optimization algorithm
# Extracting article: Modern Clustering Techniques in Wireless Sensor Networks
# Extracting article: Performance evaluation of hybrid evolutionary algorithms in minimizing localization error for wireless sensor networks
# Extracting article: Error minimization in localization of wireless sensor networks using genetic algorithm
# Extracting article: Cluster-based architecture for range-free localization in wireless sensor networks
# Extracting article: Error minimization in localization of wireless sensor networks using modified cuckoo search with mobile anchor positioning (MCS-map) algorithm
# Extracting article: Mobile adaptive distributed clustering algorithm for wireless sensor networks
# Extracting article: Telecardiology for rural health care
# Extracting article: A PSO based energy efficient clustering approach for Wireless Sensor Networks
# Extracting article: Performance analysis of broadcasting in mobile ad hoc networks using cluster approach
# Extracting article: A lexicon-based term weighting scheme for emotion identification of tweets
# Extracting article: Evolutionary approaches for minimising error in localisation of wireless sensor networks
# Extracting article: A TDMA-BASED SMART CLUSTERING TECHNIQUE FOR VANETS.
# Extracting article: Error Minimization in Localization of Wireless Sensor Networks using Ant Colony Optimization
# Extracting article: Genetic algorithm based energy efficient data gathering in wireless sensor networks
# Extracting article: Cuckoo Search with Mobile Anchor Positioning (CS-MAP) Algorithm for Error Minimization in Wireless Sensor Networks
# Extracting article: A novel image encryption method with Z-order curve and random number
# Extracting article: Distributed cluster based routing technique with multiple sinks for wireless sensor networks
# Extracting article: Adaptive Web prefetching scheme using link anchor information
# https://serpapi.com/search
# Extracting article: Graph based prediction model to improve web prefetching
# Extracting article: A rule-based expert system for ECG analysis
# Extracting article: Efficient multipath routing protocol for VANET using path restoration
# Extracting article: Improving Accuracy of Software Estimation Using Stacking Ensemble Method
# Extracting article: Swift and Energy Efficient Big Data Gathering Approaches in Wireless Sensor Networks
# Extracting article: Data Structures
# Extracting article: Power efficient scheduling technique for multiple sinks in wireless sensor networks
# Extracting article: Biometrics Based File Transmission Using RSA Cryptosystem
# Extracting article: A rule-based approach for second order model formulation of linear time invariant multivariable systems
# Extracting article: Fuzzy Based Adaptive User-Weight Classification Scheme for EDCA in IEEE 802.11 e WLAN
# Extracting article: An efficient energy harvesting assisted clustering scheme for wireless sensor networks
# Extracting article: ERROR MINIMIZATION IN LOCALIZATION OF WIRELESS SENSOR NETWORKS USING DIFFERENTIAL EVOLUTION WITH MOBILE ANCHOR POSITIONING (DE-MAP) ALGORITHM.
# Extracting article: A Novel Framework for Image Encryption using Karhunen-Loeve Transform
# Extracting article: Comparative analysis of wireless mac protocol for collision detection and collision avoidance in mobile ad hoc networks
# Extracting article: A review of consistency mechanisms for qos aware content distribution networks
# Extracting article: Improving Software Defect Prediction using Generative Adversarial Networks
# Extracting article: Energy Efficient Mobile Element Data Gathering in Wireless Sensor Networks
# Extracting article: Ranking of Authentication Schemes based on Critical Limiting Factors
# Extracting article: Background Subtraction in Surveillance Systems Using Local Spectral Histograms and Linear Regression
# Extracting article: Performance Enhancement in Multimodal Biometrics for Authentication
# https://serpapi.com/search
# Extracting article: Improved Software Defect Prediction using Transfer Learning
# Extracting article: Abstractive Text Summarization using Seq2seq Model
# Extracting article: Optimized Kohenen - Self Organizing Map (K-SOM) Neural Network predictor for Software Defect Prediction
# Extracting article: Predicting Students’ Academic Drop Out and Failures Using Data Mining Techniques
# Extracting article: Certain approaches to improve network lifetime in wireless sensor networks
# Extracting article: Steganography Based Asymmetric Key Cryptosystem Using Trellis Coded Genetic Algorithm Random Key Generator
# Extracting article: A Hierarchical Approach to Node Localization Based on Fuzzy System to Increase Network Lifetime in Wireless Sensor Networks
# Extracting article: Approaches for improving QoS provisioning in wireless LAN
# Extracting article: A Node Scheduling Game based on Water Cycle Algorithm for Energy Efficient Wireless Sensor Networks
# Extracting article: Year of Publication: 2017
# Extracting article: Accuracy improvement in software defect prediction for software management
# Extracting article: Energy aware clustering approaches For improvement of lifetime in Wireless sensor networks
# Extracting article: Protocol design for performance improvement in VANETs
# Extracting article: A Study of IEEE 802.11e WLAN with respect to QoS Issues
# Extracting article: Query Based Dynamic Clustering in Wireless Sensor Networks
# Extracting article: Threshold Based Toward Energy Efficient Big Data Gathering in Wireless Sensor Network
# Extracting article: Year of Publication: 2016
# Extracting article: Approaches to improve efficiency of data gathering in wireless sensor networks
# Extracting article: Certain new approaches for image encryption using scan pattern based pixel permutation and random number
# Extracting article: A Comparative study of various approaches used for the classification of Hyperspectral Satellite Imagery
# https://serpapi.com/search
# Extracting article: Hybrid GSA – CSSA based Emotional ELMAN Neural Network Classifier for Software Defect Prediction
# Extracting article: Enhanced Traffic Aware Scheduling Protocol for Variable Bit Rate Traffic in IEEE 802.11e WLAN
# Extracting article: Hex-Path-An Energy Efficient Path Planning Mechanism for Mobile Anchor based Localization in Wireless Sensor Networks
# Extracting article: Energy consumption models for cloud computing environment
# Extracting article: Stritng kernel approach for efficient extraction of medical information
# Extracting article: Certain approaches on error minimization in localization of wireless sensor networks using evolutionary techniques
# Extracting article: Certain clustering approaches to reduce power consumption in wireless sensor networks
# Extracting article: An Adaptive Traffic Controller With Traffic Flow Streamlining Capability
# Extracting article: Diffserv Based QoS Enhancement in IEEE 802.11e Wireless LAN using ARCR
# Extracting article: Product Metrics Based Predictive Classification of Software Using RAR Mining and Naive Bayes Approach
# Extracting article: Traffic differentiation and QoS provisioning for IEEE 802.11 e wireless LAN
# Extracting article: A POWER AWARE TRANSMISSION SCHEME SELECTION WITH DATA AGGREGATION FOR WIRELESS SENSOR NETWORKS.
# Extracting article: Certain investigations on the broadcasting in clustered mobile Ad Hoc networks
# Extracting article: Fractional Bio-Image Encryption using Karhunen-Loeve Transform
# Extracting article: Dynamic Cluster Routing Protocol for Broadcasting in Clustered Mobile Ad Hoc Networks
# Extracting article: DESIGN AND DEVELOPMENT OF CRYPTOSYSTEM USING KARHUNEN-LOEVE TRANSFORM
# Extracting article: Combining Biometric Features of Iris and Retina for Better Security Cryptography
# Extracting article: Classification of Heart Murmurs Using Wavelet Decomposition and Neural Networks
# Extracting article: Performance Analysis of IEEE 802.11 for Collision Detection and Collision Avoidance in Mobile Ad Hoc Network
# Extracting article: A Model based approach for test case generation in Object Oriented Systems
# https://serpapi.com/search
# Extracting article: An evolutionary approach for model reduction in linear time invariant discrete systems
# Extracting article: Chief Guest Session Chairs
# Extracting article: Protocol design for performance improvement in VANETs
# Extracting article: Energy Efficient Big Data Gathering using Local data Collector in Wireless Sensor Networks
# Extracting article: Approaches for improving QoS provisioning in wireless LAN
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Improved cost-based algorithm for task scheduling in cloud computing
# Extracting article: Design and implementation of an efficient two-level scheduler for cloud computing environment
# Extracting article: A novel approach to multiple sequence alignment using hadoop data grids
# Extracting article: A survey on privacy preserving association rule mining
# Extracting article: A novel parallel hybrid PSO-GA using MapReduce to schedule jobs in Hadoop data grids
# Extracting article: Performance comparison of different similarity measures for collaborative filtering technique
# Extracting article: An efficient approach to task scheduling in computational grids
# Extracting article: Modified heuristic similarity measure for personalization using collaborative filtering technique
# Extracting article: Privacy of big data: a review
# Extracting article: A novel authentication service for hadoop in cloud environment
# Extracting article: Personalized news article recommendation with novelty using collaborative filtering based rough set theory
# Extracting article: Ontology based semantic integration of heterogeneous databases
# Extracting article: A personalized online news recommendation system
# Extracting article: Corporate governance fraud detection from annual reports using big data analytics
# Extracting article: A new method for preserving privacy in quantitative association rules using DSR approach with automated generation of membership function
# Extracting article: Privacy preserving fuzzy association rule mining in data clusters using particle swarm optimization
# Extracting article: A review on prediction based autoscaling techniques for heterogeneous applications in cloud environment
# Extracting article: An efficient 3d elliptic curve Diffie–Hellman (ECDH) based two-server password-only authenticated key exchange protocol with provable security
# Extracting article: A novel parallel hybrid K-means-DE-ACO clustering approach for genomic clustering using MapReduce
# Extracting article: Power aware QoS multipath routing protocol for disaster recovery networks
# https://serpapi.com/search
# Extracting article: Adaptive Slot Allocation And Bandwidth Sharing For Prioritized Handoff Calls In Mobile Netwoks
# Extracting article: Performance evaluation of different routing protocols to minimize congestion in heterogeneous network
# Extracting article: A review on android malware: Attacks, countermeasures and challenges ahead
# Extracting article: An intelligent water drop algorithm for optimizing task scheduling in grid environment
# Extracting article: Performance analysis of different QoS routing protocols to minimize power in heterogeneous network
# Extracting article: An efficient predictive technique to autoscale the resources for web applications in private cloud
# Extracting article: A new method for preserving privacy in quantitative association rules using genetic algorithm
# Extracting article: Improved job-grouping based pso algorithm for task scheduling in grid computing
# Extracting article: Budget optimized dynamic virtual machine provisioning in hybrid cloud using fuzzy analytic hierarchy process
# Extracting article: Ontology based information retrieval for e-tourism
# Extracting article: An approach for End-to-End (E2E) security of 5G applications
# Extracting article: A novel ant based clustering of gene expression data using mapreduce framework
# Extracting article: Enhanced AOMDV for energy conservation in hybrid ad hoc networks
# Extracting article: Hypergraph-based Wikipedia search with semantics
# Extracting article: Design and development of compact monitoring system for disaster remote health centres
# Extracting article: Design and development of multipath routing protocol using QoS in heterogeneous network
# Extracting article: A Novel Trigon based Dual Authentication Protocol for Enhancing Security in Grid Environment
# Extracting article: Load balanced, efficient scheduling with parallel job submission in computational grids using parallel particle swarm optimization
# Extracting article: A Secure Android Application with Integration of Wearables for Healthcare Monitoring System Using 3D ECCDH PAKE Protocol
# Extracting article: Annotation-based document classification using shuffled frog leaping algorithm
# https://serpapi.com/search
# Extracting article: Secure communication between grid domains based on trust relationships and group keys
# Extracting article: Edge Computing: Fundamentals, Advances and Applications
# Extracting article: A survey on different consensus mechanisms for the blockchain technology
# Extracting article: Hiding Sensitive Fuzzy Association Rules Using Weighted Item Grouping and Rank Based Correlated Rule Hiding Algorithm
# Extracting article: A survey on personalized recommendation techniques
# Extracting article: Semantic similarity based web document classification using Artificial Bee Colony (ABC) algorithm
# Extracting article: Integrating an efficient authorization protocol with trigon-based authentication mechanism for improving grid security
# Extracting article: Semantic search using content based search technique with spread activation technique
# Extracting article: A Novel Real Time Scheduling Frame-work for CORBA-Based Applications.
# Extracting article: Two-server 3D ElGamal Diffie-Hellman password authenticated and key exchange protocol using geometrical properties
# Extracting article: Biclustering based collaborative filtering algorithm for personalized web service recommendation
# Extracting article: Comparative Analysis of Turbo and LDPC Codes for Reduced Storage and Retrieval of Data
# Extracting article: Personalisation of news recommendation using genetic algorithm
# Extracting article: Privacy Preservation with Attribute Reduction in Quantitative Association Rules using PSO and DSR
# Extracting article: Design of Optimal Channel Allocation for Mobile Users in Cellular Networks
# Extracting article: A prediction of the thermal conductivity of sapelli
# Extracting article: Differentially private model release for healthcare applications
# Extracting article: Anti-malware engines under adversarial attacks
# Extracting article: SafeXAI: Explainable AI to Detect Adversarial Attacks in Electronic Medical Records
# Extracting article: A review of similarity measures and link prediction models in social networks
# https://serpapi.com/search
# Extracting article: An RNN-LSTM Based Flavor Recommender Framework in Hybrid Cloud
# Extracting article: An efficient 3D Diffie-Hellman based Two-Server password-only authenticated key exchange
# Extracting article: Crop disease protection using parallel machine learning approaches
# Extracting article: A novel feature selection based on apriori property and correlation analysis for protein sequence classification using mapreduce
# Extracting article: Dynamic ontology construction for e-trading
# Extracting article: Ontology for semantic web using personalization
# Extracting article: Multi-Constrained Quality of Service Routing for Hybrid Ad Hoc Networks
# Extracting article: A Novel SLA based Task Scheduling in Grid Environment
# Extracting article: Power aware stability-based routing protocol for hybrid ad hoc networks
# Extracting article: Privacy preserving quantitative association rule mining
# Extracting article: Trigon Based Authentication Service Creation with Globus Middleware
# Extracting article: Secure group communication in grid environment
# Extracting article: Design and Implementation of a Two Level Scheduler for HADOOP Data Grids
# Extracting article: Component Based Technology
# Extracting article: Improving the performance of the IDL Compiler
# Extracting article: S., Shenoy, Sangeetha, N.(2011). Ontology Based Semantic Integration of Heterogeneous Databases
# Extracting article: Utility-based differentially private recommendation system
# Extracting article: Privacy Preserving Bloom Recommender System
# Extracting article: A critical review on using blockchain technology in education domain
# Extracting article: Malware Attacks on Electronic Health Records
# https://serpapi.com/search
# Extracting article: Classification of phonemes using EEG
# Extracting article: Gene expression data classification using MapReduce version of KNN hybridized with PSO
# Extracting article: An evolutionary approach using transactional impact factor for preserving privacy of quantitative data
# Extracting article: Hybrid Evolutionary Algorithm for Preserving Privacy of Sensitive Data in Quantitative Databases
# Extracting article: Efficiently Scheduling Hadoop Cluster in Cloud Environment
# Extracting article: Improvement in Medium Access Control Protocol based on new contention scheme for Wireless Ad hoc Network
# Extracting article: Design and implementation of a two level scheduler for HADOOP data grids
# Extracting article: A grid-based approach to paraloading using mirrored corba servers
# Extracting article: Certain Improvements In Marshalling
# Extracting article: Design and implementation of a static bridge between COM and CORBA distributed objects
# Extracting article: Privacy-aware network embedding-based ensemble for social recommendation
# Extracting article: Defense against adversarial malware using robust classifier: DAM-ROC
# Extracting article: Semantic Integration of Heterogeneous Data Sources Using Ontology-Based Domain Knowledge Modeling for Early Detection of COVID-19
# Extracting article: Prediction of Drug Bioactivity in Alzheimer’s Disease Using Machine Learning Techniques and Community Networks
# Extracting article: Requirements analysis of security and privacy of mobile payments-Indian context
# Extracting article: Multimodal screening for dyslexia using anatomical and functional MRI data
# Extracting article: Confluence of Cryptography and Differential Privacy: A Hybrid Approach for Privacy Preserving Collaborative Filtering
# Extracting article: Design of Automatic Credit Card Approval System Using Machine Learning
# Extracting article: Event Prediction for Network Edge Devices using Log Analysis
# Extracting article: Healthcare Security: Usage of Generative Models for Malware Adversarial Attacks and Defense
# https://serpapi.com/search
# Extracting article: Global Schema Generation in Healthcare
# Extracting article: Tracking students attention during video lectures using EEG
# Extracting article: Crop Yield Prediction using Granular SVM
# Extracting article: Multimodal Screening of Dyslexia using Handwriting and Eye Gaze
# Extracting article: Intelligent Social Networking in CPS
# Extracting article: Android Malware Detection
# Extracting article: A Comparative Analysis of Classical Cryptography versus Quantum Cryptography for Web of Medical Things (WoMT)
# Extracting article: Parallel Data Mining Techniques for Breast Cancer Prediction
# Extracting article: Personalized news recommendation using hybrid filtering techniques
# Extracting article: Dependability and caching enhancements in distributed systems
# Extracting article: Performance Comparison of PSO and Hybrid PSO-GA in Hiding Fuzzy Sensitive Association Rules
# Extracting article: A RNN-LSTM based Predictive Autoscaling Approach on Private Cloud
# Extracting article: Hybridized data mining techniques for sequence and gene expression data analysis using parallelization
# Extracting article: Twoserver pake protocol Based on geometrical properties For large scale distributed systems
# Extracting article: Investigations on fuzzy association rule hiding
# Extracting article: Performance evaluation of feature selection approaches for document classification
# Extracting article: DESIGN AND ANALYSIS OF ANALYTICAL MODEL OF NOVEL ENERGY CONSTRAINED COOPERATIVE MAC PROTOCOL FOR AD-HOC NETWORKS.
# Extracting article: Dynamic Ontology Construction for E-Trading.
# Extracting article: A Novel Triangle Centroid Authentication Protocol for Cloud Environment
# Extracting article: Efficient Search Structures for Wikipedia based on User Communities
# https://serpapi.com/search
# Extracting article: Grid Based Security Framework for Online Trading
# Extracting article: Secure Group Communication in Grid Environment
# Extracting article: Design and Implementation of a Novel Peer-To-Peer Information Retrieval Framework
# Extracting article: Stub Code Optimization in CORBA-Based Distributed Embedded Applications
# Extracting article: Performance analysis of distributed object middleware
# Extracting article: Design And Implementation Of A Componentised Idl Compiler
# Extracting article: Multimodal prediction of breast cancer using radiogenomics and clinical trials with decision fusion
# Extracting article: A Symmetric Two-Server Password based Authentication and Key Exchange Protocol Deployed in PaaS
# Extracting article: Energy Efficient and Reliable Job Submission in Hadoop Clusters
# Extracting article: APT–ANovell Symmetric Key Cryptographic Algorithm for Securing VPN's
# Extracting article: Hybridized data mining techniques for sequence and gene expression data analysis using parallelization
# Extracting article: A Resilient Two-Server Authentication Mechanism for Enhancing Security in Grid Environment
# Extracting article: Performance evaluation of feature selection approaches for document classification
# Extracting article: Dependability and caching enhancements in distributed systems
# Extracting article: CONGESTION REDUCTION IN HETEROGENEOUS NETWORK THROUGH QOS MULTIPATH ROUTING ALGORITHMS
# Extracting article: A Review: PAKE Security for Distributed Environment
# Extracting article: Differential Evolution Algorithm for Hiding Fuzzy Association Rules Using Mutual Information
# Extracting article: Certain investigations on performance enhancement of stub code in corba based applications
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Mammographic image enhancement using indirect contrast enhancement techniques–a comparative study
# Extracting article: A Risk Management Model for Familial Breast Cancer: A New Application using Fuzzy Cognitive Map method
# Extracting article: An Integrated breast cancer risk assessment and Risk Management model based on Fuzzy Cognitive Maps
# Extracting article: Hybrid learning of fuzzy cognitive maps for sugarcane yield classification
# Extracting article: Application of fuzzy cognitive maps in precision agriculture: a case study on coconut yield management of southern India’s Malabar region
# Extracting article: On the accuracy of centroid based multilateration procedure for location discovery in wireless sensor networks
# Extracting article: Application of fuzzy cognitive maps for crack categorization in columns of reinforced concrete structures
# Extracting article: E/sup 2/LBC: an energy efficient load balanced clustering technique for heterogeneous wireless sensor networks
# Extracting article: A survey on successive interference cancellation schemes in non-orthogonal multiple access for future radio access
# Extracting article: Application of Fuzzy Cognitive Map for geospatial dengue outbreak risk prediction of tropical regions of Southern India
# Extracting article: Getting Started with Enterprise Internet of Things: Design Approaches and Software Architecture Models
# Extracting article: Energy efficient grid clustering based data aggregation in wireless sensor networks
# Extracting article: A communication‐efficient framework for outlier‐free data reporting in data‐gathering sensor networks
# Extracting article: Fuzzy rough set inspired rate adaptation and resource allocation using Hidden Markov Model (FRSIRA-HMM) in mobile ad hoc networks
# Extracting article: An enhanced delay sensitive data packet scheduling algorithm to maximizing the network lifetime
# Extracting article: Precision agriculture: On the accuracy of multilevel and clustered ANFIS models for sugarcane yield categorization
# Extracting article: Early detection of cognitive impairment of elders using wearable sensors
# Extracting article: An Erlang Factor integrated channel allocation method for boosting quality of services in mobile ad hoc networks
# Extracting article: Design challenges for optimizing the performance of energy constrained wireless sensor networks
# Extracting article: A hybrid image enhancement scheme for mammographic images
# https://serpapi.com/search
# Extracting article: LS and MMSE based Localization Algorithm for WSNs amid obstacles
# Extracting article: A Communication Efficient Framework for Soil Moisture Monitoring using Wireless Sensor Networks
# Extracting article: A robust outlier detection scheme for collaborative sensor networks
# Extracting article: Cloud Solutions for IoT
# Extracting article: Enterprise IoT Development Platforms
# Extracting article: Machine translation using deep learning: a comparison
# Extracting article: Combined vibration and RF harvester technique for energy management in sensor device
# Extracting article: Grey Wolf Optimization-Based Big Data Analytics for Dengue Outbreak Prediction
# Extracting article: Soil Moisture Forecasting using Ensembles of Classifiers
# Extracting article: Clustering of Data with Mixed Attributes based on Unified Similarity Metric
# Extracting article: A survey on user privacy preserving blockchain for health insurance using Ethereum smart contract
# Extracting article: Edge computing in iot
# Extracting article: Safest Secure and Consistent Data Services in the Storage of Cloud Computing
# Extracting article: Agile supply chain management enabled by the internet of things and microservices
# Extracting article: A Computer-assisted Crack Predicting System for Oil and Gas Pipelines Using Fuzzy Cognitive Map
# Extracting article: A Computer-assisted Crack Predicting System for Oil and Gas Pipelines Using Fuzzy Cognitive Map
# Extracting article: A Computer-assisted Crack Predicting System for Oil and Gas Pipelines Using Fuzzy Cognitive Map
# Extracting article: Fusion of Blockchain-IoT network to improve supply chain traceability using Ethermint Smart chain: A Review
# Extracting article: Ethereum Blockchain-Based Authentication Approach for Data Sharing in Cloud Storage Model
# Extracting article: Impact of AI, BC and IoT for Smart Cities
# https://serpapi.com/search
# Extracting article: Role of Edge Computing to Leverage IoT-Assisted AAL Ecosystem
# Extracting article: Proceedings of International Conference on Artificial Intelligence, Smart Grid and Smart City Applications: AISGSC 2019
# Extracting article: A Smart Agricultural Model Using IoT, Mobile, and Cloud-Based Predictive Data
# Extracting article: Introduction to Enterprise IoT
# Extracting article: Design and Implementation of Enterprise IoT Solutions
# Extracting article: Architecture for an Enterprise IoT
# Extracting article: The Internet of Things: Connectivity Standards
# Extracting article: Agent-Based Temperature Monitoring System
# Extracting article: A Survey on Medical Image Registration Using Deep Learning Techniques
# Extracting article: A Smart Agricultural Model Using IoT, Mobile, and Cloud-Based Predictive Data Analytics
# Extracting article: Spectrum Sensing Based on Cascaded Approach for Cognitive Radios
# Extracting article: A Risk Assessment Model for Alzheimer’s Disease Using Fuzzy Cognitive Map
# Extracting article: AUTOMATED INTEGRATED CLUSTERING ALGORITHM FOR MAMMOGRAPHIC MASS SEGMENTATION
# Extracting article: Early detection of breast cancer Using image processing algorithms And estimation of overall risk
# Extracting article: Certain investigations on application of soft computing techniques for sensor data processing in precision agriculture applications
# Extracting article: Application of soft computing techniques for intelligent sensor data aggregation in structural health monitoring
# Extracting article: Application of fuzzy cognitive maps for crack categorization in columns of reinforced concrete structures
# Extracting article: Measuring Various Conflict Decision Policies in Mobile Ad Hoc Networks
# Extracting article: Application of Fuzzy Cognitive Maps for Coconut yield management in Malabar region of Southern India
# Extracting article: Early Warning System for Dengue outbreak- a preliminary approach using time series forecasting
# https://serpapi.com/search
# Extracting article: Forecasting Energy Demands based on Ensemble of Classifiers
# Extracting article: Home Energy Management for Energy Conservation using Wireless Sensor Networks
# Extracting article: Spatial-Temporal Correlation Aware Soil Moisture monitoring Framework using Wireless Sensor networks
# Extracting article: Communication Efficient Spatial-Temporal Correlation aware Soil Moisture Monitoring Framework using Wireless Sensor Networks
# Extracting article: Communication Efficient Spatial-Temporal Correlation aware Soil Moisture Monitoring Framework using Wireless Sensor Networks
# Extracting article: Coverage Problem in Wireless Sensor Networks
# Extracting article: Clustering Techniques in Wireless Sensor Networks
# Extracting article: Robust Data Aggregation Techniques in Wireless Sensor Networks
# Extracting article: Design Optimizations in Clustered Wireless Sensor Networks: A Survey
# Extracting article: ESAC: An Energy and Stability Aware Clustering for Heterogeneous Wireless Sensor Networks’
# Extracting article: An Efficient and Fault Tolerant Aggregation Scheme for Distributed Sensor Networks using Modified Z-Score Method
# Extracting article: A Report on Secure Information Processing in Wireless Sensor Networks
# Extracting article: Smart grid based residential energy Management using soft computing Techniques
# Extracting article: Comfort Management and Energy Conservation for Smart Home Environment Using Reinforcement Learning Technique
# Extracting article: Certain investigations on the energy and reliability constraints of heterogeneous wireless sensor networks
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: A comparative study of cuckoo search and bat algorithm for Bloom filter optimisation in spam filtering
# Extracting article: Enriched learning experience using augmented reality framework in engineering education
# Extracting article: Bloom filter optimization using cuckoo search
# Extracting article: An enhanced cuckoo search for optimization of bloom filter in spam filtering
# Extracting article: WITHDRAWN: Univariate and multivariate models for Short-term wind speed forecasting
# Extracting article: Early Prediction of Parkinson's Disease (PD) Using Ensemble Classifiers
# Extracting article: Skill Development through experiential learning–A case study for product development scenario
# Extracting article: Optimizing PID parameters using harmony search
# Extracting article: Optimized Bin Bloom Filter for Spam Filtering using Particle Swarm Optimization
# Extracting article: Payload inspection using parallel Bloom filter in dual core processor
# Extracting article: A Hybrid Nelder-Mead Method For Biclustering Of Gene Expression Data
# Extracting article: A Comparison study of cuckoo-bat search for Optimization of Bloom Filter in Spam Filtering
# Extracting article: Artificial immune system for bloom filter optimization
# Extracting article: Smart vehicles for urban sensing based on content-centric approach
# Extracting article: Optimized Weight Vector for QoS Aware Web Service Selection Algorithm Using Particle Swarm Optimization
# Extracting article: Bin Bloom Filter Using Heuristic Optimization Techniques for Spam Detection
# Extracting article: Combined heuristic technique for optimization of bloom filter in spam filtering
# Extracting article: Tuned Homogenous Ensemble Regressor Model for Early Diagnosis of Parkinson Disorder Based on Voice Features Modality
# Extracting article: Smart Rehabilitation Exercise Monitoring System for Knee Osteoarthritis Patients
# Extracting article: Static Localization for Underwater Acoustics Sensor Networks using Nelder-Mead algorithm for smart cities
# https://serpapi.com/search
# Extracting article: EMG based diagnosis of myopathy and neuropathy using machine learning techniques
# Extracting article: Controlled prosthesis for upper limb amputees using pattern recognition techniques
# Extracting article: An Adaptive Evolutionary approach for localization in Wireless Sensor Networks
# Extracting article: Fresh water Aqua Culturing using Under Water Sensors
# Extracting article: Type 2 Fuzzy Logic Clustering Algorithm for Multi-Hop Wireless Sensor Network for Balancing Effective Energy
# Extracting article: Evolutionary approach in localization using Tabu search algorithm for ultra-wide band sensor networks
# Extracting article: Type 2 Fuzzy Logic Clustering Algorithm for Multi-Hop Wireless Sensor Network for Balancing Effective Energy
# Extracting article: Optimization of bloom filter using evolutionary algorithm
# Extracting article: Evolutionary approach in localization using Tabu search algorithm for ultra wide band sensor network
# Extracting article: Enhanced bloom filter using heuristic optimization for spam detection
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Extractive document summarization using an adaptive, knowledge based cognitive model
# Extracting article: Contemporary cognitive architectures: a comparative study of structures and adaptability
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Personal authentication mechanism based on finger knuckle print
# Extracting article: Normalized web distance based web query classification
# Extracting article: Deep learning based assistive technology on audio visual speech recognition for hearing impaired
# Extracting article: Web knowledge and Wordnet based Automatic Web Query Classification
# Extracting article: Deep learning using python
# Extracting article: A lexicon-based term weighting scheme for emotion identification of tweets
# Extracting article: Web Query Classification Using State Space Trees., Issn: 2229-4333
# Extracting article: Multilingual low resource Indian language speech recognition and spell correction using Indic BERT
# Extracting article: Analysis on the Effect of Dropout as a Regularization Technique in Deep Averaging Network
# Extracting article: Comparative Study on Different Word Embedding Techniques
# Extracting article: A Survey on Human Elephant Conflict Hotspot Prediction and Elephant Detection and Repulsion Methods
# Extracting article: Design And Implementation Of E-Learning System Using Deep Learning Based On Audio-Video Speech Recognition For Hearing Impaired
# Extracting article: Emotion Identification in Tweets using SVM and the influence of Preprocessing on the Classifier
# Extracting article: Data Structures
# Extracting article: Directory knowledge, query stream and weighted state space tree based automatic web query classification
# Extracting article: A Markovian Approach for Automatic Web Query Classification
# Extracting article: An efficient approach to web query classification using state space trees
# Extracting article: S. Lovelyn Rose
# Extracting article: Query Stream And Web Knowledge Based Query Classification
# Extracting article: Hidden Markov Model Based Web Query Classification
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: An efficient algorithm for coverage hole detection and healing in wireless sensor networks
# Extracting article: Active Queue Management Algorithm for TCP Networks Congestion control
# Extracting article: A Secure Encrypted Classified Electronic Healthcare Data for Public Cloud Environment.
# Extracting article: Load balance technique with adaptive position updates (LAPU) for geographic routing in MANETs
# Extracting article: Video Based Vehicle Counting Using Deep Learning Algorithms
# Extracting article: Performance Analysis of Parallel K-Means with Optimization Algorithms for clustering on Spark
# Extracting article: A new approach to Active Queue Management for TCP with ECN
# Extracting article: Stego-Audio Using Genetic Algorithm Approach
# Extracting article: Comparison of Congestion Control Algorithms in Healthcare Wireless Sensor Networks
# Extracting article: Hybrid optimized convolutional neural network for efficient classification of ECG signals in healthcare monitoring
# Extracting article: Performance Analysis of Active Queue Management Algorithms
# Extracting article: A wireless sensor network for remote detection of arrhythmias using convolutional neural network
# Extracting article: An optimized multiobjective CPU job scheduling using evolutionary algorithms
# Extracting article: NEWQUE: A New Approach to Active Queue Management for TCP with ECN
# Extracting article: IoT based Door open or close monitoring for home security with emergency notification system using LoRa Technology
# Extracting article: Real Time Mold Quality Inspection in Foundries using Image Processing Techniques
# Extracting article: Optimal sentence clustering for web database using hierarchical fuzzy relational clustering integrated with artificial bee colony algorithm
# Extracting article: An Efficient Algorithm for Job Scheduling Problem-Enhanced Artificial Bee Colony Algorithm
# Extracting article: NEWQUE with per-flow scheduling: Performance improvement of active queue management algorithm
# Extracting article: Robotic Assistants from Personalized Care to Disease Diagnosis and Treatment Plans in Healthcare Applications
# https://serpapi.com/search
# Extracting article: Comparative Analysis on Image Retrieval Technique using Machine Learning
# Extracting article: DIMENSIONALITY REDUCTION BY INTRINSIC DIMENSION ESTIMATION USING BOX COUNTING METHOD AND CORRELATION DIMENSION METHOD
# Extracting article: i-Shopping with Sensor Fusion for finding Customer Behavior using Deep Learning Algorithm
# Extracting article: Internet Traffic Classification using Machine Learning
# Extracting article: Dimensionality Reduction by Intrinsic Dimension Estimation Using Box counting method and Correlation dimension Method
# Extracting article: An Optimized Multi-Objective CPU Job Scheduling in Distributed Computing Systems using Firefly Algorithm
# Extracting article: An Efficient Algorithm for Job Scheduling Problem-Enhanced Artificial Bee Colony Algorithm
# Extracting article: A New Fair Active Queue Management Algorithm for Improving Unresponsive Flow Control
# Extracting article: Implementing Queue Data structure for Crawler Module
# Extracting article: Optimal Sentence Clustering using Hierarchical Fuzzy Relational Clustering integrated with Artificial Bee Colony algorithm
# Extracting article: Load balance technique with Adaptive Position Updates for Geographic Routing in MANETs
# Extracting article: PerNEWQUE: An Active Queue Management for controlling Unresponsive flows
# Extracting article: MNEWQUE: A New Approach to TCP/AQM with ECN
# Extracting article: Performance Improvement on the Robustness of TCP/Active Queue Management with ECN
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Modified ant colony algorithm for grid scheduling
# Extracting article: Hybrid enhanced ant colony algorithm and enhanced bee colony algorithm for grid scheduling
# Extracting article: A Survey on Supervised and Unsupervised Learning Techniques
# Extracting article: Web based testing—an optimal solution to handle peak load
# Extracting article: Enhanced bee colony algorithm for complex optimization problems
# Extracting article: A Complete Survey on Association Rule Mining with Relevance to Different Domain
# Extracting article: An Improved Ant Colony Algorithm for Effective Mining of Frequent Items
# Extracting article: A Hybrid k-DCI and Apriori Algorithm for Mining Frequent Itemsets
# Extracting article: Ameliorated face and iris recognition using deep convolutional networks
# Extracting article: Computational Linguistics‐Based Tamil Character Recognition System for Text to Speech Conversion
# Extracting article: Selective Marketing for Retailers to promote Stock using improved Ant Colony Algorithm
# Extracting article: Human-computer interaction system for improving digital literacy among speech-and hearing-impaired in developing countries
# Extracting article: Intelligent character recognition system using convolutional neural network
# Extracting article: Performance Analysis of Breast Cancer Detection Method Using ANFIS Classification Approach
# Extracting article: Deep Learning Based Hybrid Approach For Facial Emotion Detection
# Extracting article: Online Hostel Management System Using Hybridized Techniques of Random Forest Algorithm and Long Short-Term Memory
# Extracting article: Smart Attendance Monitoring IOT based Device using Cloud Services
# Extracting article: Design of UML Diagrams for WEBMED-Healthcare Service System Services
# Extracting article: Online Assessment System Using Natural Language Processing Techniques
# Extracting article: Facial Emotion Detection using Deep Learning Techniques (BEST PAPER AWARD)
# https://serpapi.com/search
# Extracting article: Design of UML Diagrams for Intervention for Autism Children (IAC System)
# Extracting article: Super-Resolution-Based Human-Computer Interaction System for Speech and Hearing Impaired Using Real-Time Hand Gesture Recognition System
# Extracting article: Tamil Character Recognition using Deep Learning Algorithms
# Extracting article: Survey on Tamil Character Recognition using Deep Learning Algorithms
# Extracting article: Social Distance Monitoring using Machine Learning Techniques
# Extracting article: Real-time social distance alerting and contact tracing using image processing
# Extracting article: Enhanced End-to-End System for Autonomous Driving Using Deep Convolutional Networks
# Extracting article: Missing Values and Class Prediction Based on Mutual Information and Supervised Similarity
# Extracting article: Computational Linguistics Based Tamil Character Recognition System for Text to Speech Conversion (BEST PAPER AWARD)
# Extracting article: SENTIMENTAL ANALYSIS OF TWITTER USING LONG SHORT-TERM MEMORY AND GATE RECURRENT UNIT
# Extracting article: ONLINE HOSTEL MANAGEMENT USING LONG SHORT-TERM MEMORY
# Extracting article: Solving Travelling Salesman Problem using an Enhanced Ant Colony Algorithm
# Extracting article: A Dynamic Approach to Control Traffic Using Sensor Cloud Infrastructure
# Extracting article: Profitable Resource Allocation using Map Reduce with CURA Techniques
# Extracting article: PROFITABLE RESOURCE ALLOCATION USING MAP REDUCE WITH CURA TECHNIQUES
# Extracting article: Continuous Monitoring of Critical Patients Using Sensor Data Mining Technique
# Extracting article: “A Novel Approach for Applying Text Mining to Analyse E-Commerce Feedback Comments”
# Extracting article: COMPARISON OF HYBRID APPROACHES WITH TRADITIONAL ALGORITHMS FOR IMPROVING SCALABILITY OF FREQUENT PATTERN MINING
# Extracting article: Lexicographic Tree for Efficient Handling of Frequent Patterns
# Extracting article: Enhanced Artificial Bee Colony Algorithm for Effective Frequent Pattern Mining
# https://serpapi.com/search
# Extracting article: SURVEY ON ARTIFICIAL BEE COLONY ALGORITHM
# Extracting article: Frequent Pattern Mining Using Lexicographic Tree Representation
# Extracting article: A Survey on Child Care Knowledge Mining System
# Extracting article: Modified Bee Colony Algorithm for Optimization Problems
# Extracting article: Survey of Ontologies in Different Domains of Mining
# Extracting article: Mining of Frequent Item sets using Association Rule Mining in WEKA Environment
# Extracting article: Mining Frequent Items using Compressed Data Structures
# Extracting article: PROFITABLE RESOURCE ALLOCATION USING MAP REDUCE WITH CURA TECHNIQUES
# Extracting article: Enhanced ant colony algorithm to improve scalability of frequent pattern mining
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: A collaborative search with query expansion and result re-ranking
# Extracting article: Personalized Information Retrieval System using Temporal ranking
# Extracting article: Software Agent Based Search Engine Using Grid Technology
# Extracting article: Search Query Expansion using Genetic Algorithm–based Clustering
# Extracting article: Superiority of agent based search in advanced educational technology
# Extracting article: Optical Character Recognition using Deep Neural Network
# Extracting article: Certain investigations on web search personalisation using concept clusters
# Extracting article: A Concept based clustering approach for Web Search Personalization
# Extracting article: Agent based Collaborative filtering to improve personalised search
# Extracting article: Development of Computer Vision Algorithm for the calibration of the tube locator module for Steam generator Inspection
# Extracting article: Unsupervised Duplicate Detection over Query Results from Multiple Search Engines
# Extracting article: Improvising Web Search Using Concept Based Clustering
# Extracting article: Query Expansion Using Concept-based Clustering
# Extracting article: Text Clustering With Multiviewpoints
# Extracting article: Personalization of web search using soft computing techniques
# Extracting article: Personalized Search query Clustering
# Extracting article: Search query recommendations based on user access patterns
# Extracting article: Personalized Information Retrieval system,
# ...
# Extracting article: New approach to cryptographic ciphering using chessboard movement combinatorics
# Extracting article: Indexed Keyword Search using Inverted Lists
# Extracting article: Enhancing search engines through intelligent indexing and ranking methods
# Extracting article: Desktop Searching Made Easy By Using An Intelligent Agent
# Extracting article: Aptness of Mobile agents for Intelligent Distributed Searching
# Extracting article: A novel approach on intelligent searching
# Extracting article: Suitability of multiagents for intelligent distributed searching
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: A conceptual framework for ontology based information retrieval
# Extracting article: Ontology based comprehensive architecture for service discovery in emergency cloud
# Extracting article: Investigation on blockchain technology for web service composition: a case study
# Extracting article: Comparison of Web Service Similarity-Assessment Methods
# Extracting article: I/O Match (I/O MAT) and Behavioural Match (BEH MAT) Based Semantic Web Service Discovery
# Extracting article: Integrating blockchain technology in 5G-enabled smart healthcare: a SWOT analysis
# Extracting article: Cyber Physical Systems for Disaster Response NetworksConceptual Proposal using Never Ceasing Network
# Extracting article: Cyber Physical Systems for Disaster Response Networks
# Extracting article: Smart Cyber Physical Systems: Advances, Challenges and Opportunities
# Extracting article: Multi-Level Colour Image Segmentation Using Differential Evolution
# Extracting article: Cloud Based Comprehensive Architecture (CBCA) for QoS Aware Semantic Web Service Discovery in Emergency Management System
# Extracting article: Self-Organizing Agent based Framework for Service Discovery in Cloud
# Extracting article: Secured Data Transmission in Adhoc Networks Supporting Heterogeneous Interfaces
# Extracting article: Blockchain Technology and its Applications-An Overview
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: A Comparative Sentiment Analysis Of Sentence Embedding Using Machine Learning Techniques
# Extracting article: A survey on privacy preserving Association rule mining
# Extracting article: A new method for preserving privacy in quantitative association rules using DSR approach with automated generation of membership function
# Extracting article: Privacy preserving fuzzy association rule mining in data clusters using particle swarm optimization
# Extracting article: A New Method for preserving privacy in Quantitative Association Rules using Genetic Algorithm
# Extracting article: Hiding Sensitive Fuzzy Association Rules Using Weighted Item Grouping and Rank Based Correlated Rule Hiding Algorithm
# Extracting article: Privacy Preservation with Attribute Reduction in Quantitative Association Rules using PSO and DSR
# Extracting article: Protecting the privacy of cancer patients using fuzzy association rule hiding
# Extracting article: Privacy Preserving Quantitative Association Rule Mining
# Extracting article: An Evolutionary Approach using Transactional Impact Factor for Preserving Privacy of Quantitative Data
# Extracting article: Hybrid Evolutionary Algorithm for Preserving Privacy of sensitive data in Quantitative Databases
# Extracting article: Performance Comparison of PSO and Hybrid PSO-GA in Hiding Fuzzy Sensitive Association Rules
# Extracting article: Investigations on fuzzy association rule hiding
# Extracting article: Hiding Sensitive Association Rules for Quantitative Data using Quantitative Condensed Frequency
# Extracting article: Differential Evolution Algorithm for Hiding Fuzzy Association Rules Using Mutual Information
# Extracting article: Protecting sensitive Fuzzy Association Rules in on Trusted Third Party Model
# Extracting article: Hybrid Evolutionary Algorithm for Privacy Preserving Quantitative Association Rule Mining
# Extracting article: Hiding Quantitative Sensitive Association Rules
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Vehicle identification and authentication system
# Extracting article: A New Symmetric Cryptosystem using Randomized Parameters of SHA-512 and MD5 Hash Functions
# Extracting article: Generation of random key stream using word grid puzzle for the applications of cryptography
# Extracting article: Novel Approach for Online Identity Management System using AADHAAR Unique Identification Number
# Extracting article: We Bring Your Identity: A Secure Online Passenger Identity Protocol (SOPIP) for Indian Railways Using Aadhaar Number
# Extracting article: STEGANOGRAPHY BASED ASYMMETRIC KEY CRYPTOSYSTEM USING TRELLIS CODED GENETIC ALGORITHM RANDOM KEY GENERATOR
# Extracting article: PSEUDO RANDOM NUMBER GENERATION USING EYE BRIGHTNESS RESPONSE
# Extracting article: IMAGE ENCRYPTION AND DECRYPTION SYSTEM FOR ENCRYPTING/DECYPTING AN IMAGE BASED ON A CALLIGRAPHY PATTERN
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Comparative Analysis of Turbo and LDPC Codes for Reduced Storage and Retrieval of Data
# Extracting article: Analysis of Heart Disease Prediction Using Machine Learning Techniques
# Extracting article: Detection of Brain Tumor Using Convolutional Neural Network in medical Imaging
# Extracting article: SYSTEMATIZED IMAGE PROCESSING BASED MALARIA DIAGNOSTIC SYSTEM
# Extracting article: Detection of Brain Tumor in Medical Imaging
# Extracting article: Comparative Study on Object Detection Models
# Extracting article: Diagnosis of Liver Disease using Particle Swarm Optimization
# Extracting article: A New Improved Election Algorithm for Achieving High Availability in Distributed Systems
# Extracting article: High Availability in HDFS: Forming Distributed Cluster of NameNodes.
# Extracting article: A New Collaborative Caching Technique To Improve Performance on Data Storage In Hadoop
# Extracting article: A NOVEL APPROACH TO TORNADO CODES FOR ARCHIVAL STORAGE SYSTEM
# Extracting article: A Novel Approach to Enhance Reliability in Hadoop with Reduced Storage Requirement
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Crop Yield Prediction Analysis using Feed Forward and Recurrent Neural Network
# Extracting article: Comparitive Analysis of Clustering Techniques in Anomaly Detection in Wind Turbine Data
# Extracting article: Enhanced Mass Vehicle Surveillance System
# Extracting article: An Empirical Analysis of Hierarchical and Partition Based Clustering Techniques in Optic Disc Segmentation
# Extracting article: Predicting Flight Delay using ANN with Multi-core Map Reduce Framework
# Extracting article: Image captioning using R-CNN & LSTM deep learning model
# Extracting article: Development and validation of a stability-indicating high performance liquid chromatographic assay for rifaximin in bulk and pharmaceutical dosage forms
# Extracting article: Automatic localization of optic disc in retinal fundus image based on unsupervised learning
# Extracting article: A Comparative Analysis of Deep Learning Models to Predict Dermatological Disorder
# Extracting article: Comparative Analysis of Machine Learning Techniques for Crop Yield Prediction
# Extracting article: A novel JAYA algorithm for optic disc localisation in eye fundus images
# Extracting article: A comparison of different surrogate models for delamination detection in composite laminates using experimental modal analysis
# Extracting article: Impact Analysis and Combating of COVID-19 around the World
# Extracting article: Exploration of Computational Intelligence Insights and Data Analytics to Combat COVID-19
# Extracting article: JAYA Algorithm Versus Differential Evolution: A Comparative Case Study on Optic Disc Localization in Eye Fundus Images
# Extracting article: Detection of Covid-19 Severity with CT Scan Images using Segmentation Techniques
# Extracting article: Bioinformatics and Medical Applications: Big Data Using Deep Learning Algorithms
# Extracting article: Heart Disease Classification Using Regional Wall Thickness by Ensemble Classifier
# Extracting article: Intelligent Student Companion
# Extracting article: Optic Disc Detection in Fundus Eye Images – A Detailed Survey
# https://serpapi.com/search
# Extracting article: Comparative Analysis of Prediction Model In Weather Forecasting System For Agricultural Development
# Extracting article: 3D - Learning Representations From Audio Using Autoencoders
# Extracting article: Job Recommendation System Using Keyword Parser
# Extracting article: Privacy Preserving Data Publishing Using Slicing Technique
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Image segmentation using artificial neural network and genetic algorithm: a comparative analysis
# Extracting article: Evolutionary algorithm for overlapping community detection using a merged maximal cliques representation scheme
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Performance comparison of different similarity measures for collaborative filtering technique
# Extracting article: Modified heuristic similarity measure for personalization using collaborative filtering technique
# Extracting article: Personalized news article recommendation with novelty using collaborative filtering based rough set theory
# Extracting article: A personalized online news recommendation system
# Extracting article: Crop yield prediction, forecasting and fertilizer recommendation using voting based ensemble classifier
# Extracting article: Text dependent writer identification using support vector machine
# Extracting article: Ofstf with Non Linear to Linear Equation Method-An Optimal Solution for Transportation Problem
# Extracting article: An interactive Tool for Writer Identification based on Offline Text Dependent Approach
# Extracting article: Hypergraph-based Wikipedia search with semantics
# Extracting article: A survey on different consensus mechanisms for the blockchain technology
# Extracting article: Phytochemical screening and biosynthesis of silver nanoparticles of selected medicinal plants used in traditional medicine
# Extracting article: A survey on personalized recommendation techniques
# Extracting article: A Novel Real Time Scheduling Frame-work for CORBA-Based Applications.
# Extracting article: Biclustering based collaborative filtering algorithm for personalized web service recommendation
# Extracting article: Personalisation of news recommendation using genetic algorithm
# Extracting article: Crop yield prediction, forecasting and fertilizer recommendation using Data mining algorithm
# Extracting article: Markovian process and novel secure algorithm for big data in two-hop wireless networks
# Extracting article: Ontology for semantic web using personalization
# Extracting article: An Intense Study on Intelligent Service Provisioning for Multi-Cloud Based on Machine Learning Techniques
# Extracting article: Building a Scalable Eservice Recommender System
# https://serpapi.com/search
# Extracting article: Wireless transmission of big data using novel secure algorithm
# Extracting article: A review on sustainable biodiversity challenges and opportunities
# Extracting article: Sustainable Development for Smart Cities: Challenges and Opportunities
# Extracting article: Intrusion Detection and Prevention Schemes for Cyber Physical Systems: An Empirical Study
# Extracting article: Clustering Reporeapers Using Data Mining Techniques
# Extracting article: QUALITY CHECK IN ENGINEERING DIAGRAM USING OPTICAL CHARACTER RECOGNITION
# Extracting article: A Comprehensive Survey on Artificial Intelligence and Machine Learning Techniques
# Extracting article: Early diagnosis of stroke disorder using homogenous logistic regression ensemble classifier
# Extracting article: A Comprehensive Survey on Artificial Intelligence and Machine Learning Techniques
# Extracting article: A comprehensive review of Machine Learning Based methods for Parkinson Disease prediction
# Extracting article: A SURVEY ON DOCUMENT CLASSIFICATION USING DEEP LEARNING TECHNIQUES
# Extracting article: FOOD IMAGE CLASSIFICATION BASED ON NUTRITION INFORMATION USING MACHINE LEARNING TECHNIQUES
# Extracting article: Personalized news recommendation using hybrid filtering techniques
# Extracting article: Secure Authorized Deduplication with Data Mining in Cloud
# Extracting article: Grid Based Security Framework for Online Trading
# Extracting article: A Comprehensive Survey on Artificial Intelligence and Machine Learning Techniques
# Extracting article: A comprehensive and heuristic approach for Personalized Web Search using Greedy Algorithm
# Extracting article: Content-Based Recommendation for Web Personalization
# Extracting article: A Review on Advanced Algorithms in Recommender Systems
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Application of improved apriori in university library
# Extracting article: Knn and arl based imputation to estimate missing values
# Extracting article: Overview of real time decision support system
# Extracting article: Study on Pattern Revealing in Text Mining
# Extracting article: Semantic Integration of Heterogeneous Data Sources Using Ontology Based Domain Knowledge Modeling for Early Detection of COVID 19
# Extracting article: A survey on ontology techniques deployed in the biomedical domain
# Extracting article: Global Schema Generation in Healthcare
# Extracting article: Hybrid Query System
# Extracting article: Smart Toll System
# Extracting article: Query System for MYSQL and MONGODB
# Extracting article: Ameliorated end-to-end deep learning system for self learning cars
# Extracting article: Item Feature ranking
# Extracting article: Document Clustering by a Fuzzy Based Approach
# Extracting article: Item & Features Ranking Based on User Item Interaction
# Extracting article: Rising up the Marketing Tactics by Looking out the Key Users
# Extracting article: Graph Api for Facebook Related Data
# Extracting article: Improved ARL Imputation to estimate missing values and predicting of future values
# Extracting article: Dynamic and randomized Query Optimization algorithms to improve optimality of access plans
# Extracting article: Faster Prediction of Missing Items in Shopping Carts using FUFP _ DSARM
# Extracting article: SQL Injection Attack Valnerability Detection Technique
# https://serpapi.com/search
# Extracting article: Hybrid Apriori Algorithem An Efficient Approach to find frequent itemsets
# Extracting article: Comparing the computational complexity and accuracy of classification algorithms
# Extracting article: Comparing the Efficiency of classification Algorithms Using Decision Trees
# Extracting article: Evolution of pioneering classifier algorithm using decision trees
# Extracting article: Data Mining for Image Database
# Extracting article: Data warehousing Issues and Implementation
# Extracting article: PERFORMANCE EVALUATION BETWEEN APRIORI AND IMPROVED APRIORI
# Extracting article: Faster Prediction of Missing Items in Shopping Carts using FUFP-DSARM
# Extracting article: Predicting Missing Items in Shopping Carts
# Extracting article: Pattern Discovery using Pattern Revealing in Text Mining
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Extracting article: Secure online voting system in cloud
# Extracting article: Authentication as a service in cloud from a fuzzy perspective
# Extracting article: Self organizing blockchain enabled security framework for online voting
# Extracting article: Using Petri-Net for Modeling and Formal Verification of Crypto-security in Driverless Vehicles
# Extracting article: An Agent Based Online Voting System in Cloud Using Blind Signature
# Extracting article: Blockchain Technology and its Applications-An Overview
# https://serpapi.com/search
# https://serpapi.com/search

# %%
len(author_data)
# Out:
# 27

# %%
author_data1 = author_data

# %%
author_data1 = [i for i in author_data if i!={}]

# %%
len(author_data1)
# Out:
# 18

# %%
for i in author_data1:
  print(len(i))
# Out:
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13

# %%
df_author = pd.DataFrame(author_data1)

# %%
df_author.to_csv('/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/author_data_cse.csv')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/author_data_cse.csv')
df1.head()
# Out:
#    Unnamed: 0               name                                email  \
# 0           0       R Venkatesan      Verified email at psgtech.ac.in
# 1           1  G Sudha Sadasivam      Verified email at psgtech.ac.in
# 2           2     Jayashree L.S.                    No verified email
# 3           3    Dr. N Arulanand      Verified email at psgtech.ac.in
# 4           4      Marx Rajangam  Verified email at cse.psgtech.ac.in
#
#                                              website  \
# 0                                                NaN
# 1                                                NaN
# 2        https://www.psgtech.edu/facgen.php?id=C6010
# 3                                                NaN
# 4  http://www.psgtech.edu/department/cse/faculty....
#
#                                            interests  \
# 0  [{'title': 'Data structures', 'link': 'https:/...
# 1  [{'title': 'Data Analytics', 'link': 'https://...
# 2  [{'title': 'Internet of Things', 'link': 'http...
# 3  [{'title': 'Embedded Systems', 'link': 'https:...
# 4  [{'title': 'Artificial Intelligence', 'link': ...
#
#                                         affiliations  \
# 0  professor of computer science and engineering,...
# 1          Professor, CSE, PSG College of technology
# 2                          PSG College of Technology
# 3  Professor, Department of Computer Science and ...
# 4                          PSG College of Technology
#
#                                            thumbnail  \
# 0  https://scholar.googleusercontent.com/citation...
# 1  https://scholar.google.com/citations/images/av...
# 2  https://scholar.googleusercontent.com/citation...
# 3  https://scholar.googleusercontent.com/citation...
# 4  https://scholar.google.com/citations/images/av...
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 787, 'since_2018': 438}...
# 1  [{'citations': {'all': 1120, 'since_2018': 533...
# 2  [{'citations': {'all': 507, 'since_2018': 363}...
# 3  [{'citations': {'all': 154, 'since_2018': 87}}...
# 4  [{'citations': {'all': 12, 'since_2018': 12}},...
#
#                                       cited_by_graph  public_access_link  \
# 0  [{'year': 2006, 'citations': 3}, {'year': 2007...                 NaN
# 1  [{'year': 2009, 'citations': 6}, {'year': 2010...                 NaN
# 2  [{'year': 2007, 'citations': 4}, {'year': 2008...                 NaN
# 3  [{'year': 2012, 'citations': 3}, {'year': 2013...                 NaN
# 4  [{'year': 2019, 'citations': 1}, {'year': 2020...                 NaN
#
#    public_access_available  public_access_not_available  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#                                           co_authors  \
# 0  [{'name': 'Dr.T.Sivakumar', 'link': 'https://s...
# 1  [{'name': 'K G Saranya', 'link': 'https://scho...
# 2  [{'name': 'Elpiniki Papageorgiou', 'link': 'ht...
# 3  [{'name': 'K Premalatha', 'link': 'https://sch...
# 4  [{'name': 'A Chitra', 'link': 'https://scholar...
#
#                                                 link
# 0  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 1  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 2  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 3  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 4  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...

# %%
article_title = []
article_year = []
authors = []
journals = []
publication = []
article_link = []
for i in df1['link']:
  df2 = pd.read_csv(i)
  article_title.append(list(df2['article_title']))
  article_year.append(list(df2['article_year']))
  authors.append(list(df2['article_citation_id']))
  journals.append(list(df2['article_authors']))
  article_link.append(list(df2['article_link']))

# %%
df1['article_title'] = article_title
df1['article_published_year'] = article_year
df1['authors'] = authors
df1['journals'] = journals
df1['article_link'] = article_link

# %%
df1.head()
# Out:
#    Unnamed: 0               name                                email  \
# 0           0       R Venkatesan      Verified email at psgtech.ac.in
# 1           1  G Sudha Sadasivam      Verified email at psgtech.ac.in
# 2           2     Jayashree L.S.                    No verified email
# 3           3    Dr. N Arulanand      Verified email at psgtech.ac.in
# 4           4      Marx Rajangam  Verified email at cse.psgtech.ac.in
#
#                                              website  \
# 0                                                NaN
# 1                                                NaN
# 2        https://www.psgtech.edu/facgen.php?id=C6010
# 3                                                NaN
# 4  http://www.psgtech.edu/department/cse/faculty....
#
#                                            interests  \
# 0  [{'title': 'Data structures', 'link': 'https:/...
# 1  [{'title': 'Data Analytics', 'link': 'https://...
# 2  [{'title': 'Internet of Things', 'link': 'http...
# 3  [{'title': 'Embedded Systems', 'link': 'https:...
# 4  [{'title': 'Artificial Intelligence', 'link': ...
#
#                                         affiliations  \
# 0  professor of computer science and engineering,...
# 1          Professor, CSE, PSG College of technology
# 2                          PSG College of Technology
# 3  Professor, Department of Computer Science and ...
# 4                          PSG College of Technology
#
#                                            thumbnail  \
# 0  https://scholar.googleusercontent.com/citation...
# 1  https://scholar.google.com/citations/images/av...
# 2  https://scholar.googleusercontent.com/citation...
# 3  https://scholar.googleusercontent.com/citation...
# 4  https://scholar.google.com/citations/images/av...
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 787, 'since_2018': 438}...
# 1  [{'citations': {'all': 1120, 'since_2018': 533...
# 2  [{'citations': {'all': 507, 'since_2018': 363}...
# 3  [{'citations': {'all': 154, 'since_2018': 87}}...
# 4  [{'citations': {'all': 12, 'since_2018': 12}},...
#
#                                       cited_by_graph  public_access_link  \
# 0  [{'year': 2006, 'citations': 3}, {'year': 2007...                 NaN
# 1  [{'year': 2009, 'citations': 6}, {'year': 2010...                 NaN
# 2  [{'year': 2007, 'citations': 4}, {'year': 2008...                 NaN
# 3  [{'year': 2012, 'citations': 3}, {'year': 2013...                 NaN
# 4  [{'year': 2019, 'citations': 1}, {'year': 2020...                 NaN
#
#    public_access_available  public_access_not_available  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#                                           co_authors  \
# 0  [{'name': 'Dr.T.Sivakumar', 'link': 'https://s...
# 1  [{'name': 'K G Saranya', 'link': 'https://scho...
# 2  [{'name': 'Elpiniki Papageorgiou', 'link': 'ht...
# 3  [{'name': 'K Premalatha', 'link': 'https://sch...
# 4  [{'name': 'A Chitra', 'link': 'https://scholar...
#
#                                                 link  \
# 0  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 1  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 2  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 3  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 4  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
#
#                                        article_title  \
# 0  [A SURVEY ON AUTOMATIC TEST CASE GENERATION, A...
# 1  [Improved cost-based algorithm for task schedu...
# 2  [Mammographic image enhancement using indirect...
# 3  [A comparative study of cuckoo search and bat ...
# 4  [Extractive document summarization using an ad...
#
#                               article_published_year  \
# 0  [sox193AAAAAJ:qxL8FJ1GzNcC, sox193AAAAAJ:Wp0gI...
# 1  [1TCSp8sAAAAJ:RGFaLdJalmkC, 1TCSp8sAAAAJ:kzcrU...
# 2  [mmNPmLoAAAAJ:vV6vV6tmYwMC, mmNPmLoAAAAJ:35N4Q...
# 3  [cLqiFpwAAAAJ:LkGwnXOMwfcC, cLqiFpwAAAAJ:Y0pCk...
# 4  [l8aYEJcAAAAJ:u-x6o8ySG0sC, l8aYEJcAAAAJ:u5HHm...
#
#                                              authors  \
# 0  [M Prasanna, SN Sivanandam, R Venkatesan, Sund...
# 1  [S Selvarani, GS Sadhasivam, R Jayarani, S Sad...
# 2  [K Akila, LS Jayashree, A Vasuki, Elpiniki I. ...
# 3  [A Natarajan, S Subramanian, K Premalatha, N A...
# 4  [M Rajangam, C Annamalai, M Rajangam, C Annama...
#
#                                             journals  \
# 0  [Academic Open Internet Journal 15, 2005, IETE...
# 1  [2010 IEEE International Conference on Computa...
# 2  [Procedia Computer Science 47, 255-261, 2015, ...
# 3  [International Journal of Bio-Inspired Computa...
# 4  [Cognitive Systems Research 56, 56-71, 2019, I...
#
#                                         article_link
# 0  [https://scholar.google.com/citations?view_op=...
# 1  [https://scholar.google.com/citations?view_op=...
# 2  [https://scholar.google.com/citations?view_op=...
# 3  [https://scholar.google.com/citations?view_op=...
# 4  [https://scholar.google.com/citations?view_op=...

# %%
df1.drop(columns = ['Unnamed: 0'], inplace = True)

# %% [markdown]
# # Pre_Process

# %% [markdown]
# ## 1

# %%
df1.head()
# Out:
#                 name                                email  \
# 0       R Venkatesan      Verified email at psgtech.ac.in
# 1  G Sudha Sadasivam      Verified email at psgtech.ac.in
# 2     Jayashree L.S.                    No verified email
# 3    Dr. N Arulanand      Verified email at psgtech.ac.in
# 4      Marx Rajangam  Verified email at cse.psgtech.ac.in
#
#                                              website  \
# 0                                                NaN
# 1                                                NaN
# 2        https://www.psgtech.edu/facgen.php?id=C6010
# 3                                                NaN
# 4  http://www.psgtech.edu/department/cse/faculty....
#
#                                            interests  \
# 0  [{'title': 'Data structures', 'link': 'https:/...
# 1  [{'title': 'Data Analytics', 'link': 'https://...
# 2  [{'title': 'Internet of Things', 'link': 'http...
# 3  [{'title': 'Embedded Systems', 'link': 'https:...
# 4  [{'title': 'Artificial Intelligence', 'link': ...
#
#                                         affiliations  \
# 0  professor of computer science and engineering,...
# 1          Professor, CSE, PSG College of technology
# 2                          PSG College of Technology
# 3  Professor, Department of Computer Science and ...
# 4                          PSG College of Technology
#
#                                            thumbnail  \
# 0  https://scholar.googleusercontent.com/citation...
# 1  https://scholar.google.com/citations/images/av...
# 2  https://scholar.googleusercontent.com/citation...
# 3  https://scholar.googleusercontent.com/citation...
# 4  https://scholar.google.com/citations/images/av...
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 787, 'since_2018': 438}...
# 1  [{'citations': {'all': 1120, 'since_2018': 533...
# 2  [{'citations': {'all': 507, 'since_2018': 363}...
# 3  [{'citations': {'all': 154, 'since_2018': 87}}...
# 4  [{'citations': {'all': 12, 'since_2018': 12}},...
#
#                                       cited_by_graph  public_access_link  \
# 0  [{'year': 2006, 'citations': 3}, {'year': 2007...                 NaN
# 1  [{'year': 2009, 'citations': 6}, {'year': 2010...                 NaN
# 2  [{'year': 2007, 'citations': 4}, {'year': 2008...                 NaN
# 3  [{'year': 2012, 'citations': 3}, {'year': 2013...                 NaN
# 4  [{'year': 2019, 'citations': 1}, {'year': 2020...                 NaN
#
#    public_access_available  public_access_not_available  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#                                           co_authors  \
# 0  [{'name': 'Dr.T.Sivakumar', 'link': 'https://s...
# 1  [{'name': 'K G Saranya', 'link': 'https://scho...
# 2  [{'name': 'Elpiniki Papageorgiou', 'link': 'ht...
# 3  [{'name': 'K Premalatha', 'link': 'https://sch...
# 4  [{'name': 'A Chitra', 'link': 'https://scholar...
#
#                                                 link  \
# 0  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 1  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 2  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 3  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 4  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
#
#                                        article_title  \
# 0  [A SURVEY ON AUTOMATIC TEST CASE GENERATION, A...
# 1  [Improved cost-based algorithm for task schedu...
# 2  [Mammographic image enhancement using indirect...
# 3  [A comparative study of cuckoo search and bat ...
# 4  [Extractive document summarization using an ad...
#
#                               article_published_year  \
# 0  [sox193AAAAAJ:qxL8FJ1GzNcC, sox193AAAAAJ:Wp0gI...
# 1  [1TCSp8sAAAAJ:RGFaLdJalmkC, 1TCSp8sAAAAJ:kzcrU...
# 2  [mmNPmLoAAAAJ:vV6vV6tmYwMC, mmNPmLoAAAAJ:35N4Q...
# 3  [cLqiFpwAAAAJ:LkGwnXOMwfcC, cLqiFpwAAAAJ:Y0pCk...
# 4  [l8aYEJcAAAAJ:u-x6o8ySG0sC, l8aYEJcAAAAJ:u5HHm...
#
#                                              authors  \
# 0  [M Prasanna, SN Sivanandam, R Venkatesan, Sund...
# 1  [S Selvarani, GS Sadhasivam, R Jayarani, S Sad...
# 2  [K Akila, LS Jayashree, A Vasuki, Elpiniki I. ...
# 3  [A Natarajan, S Subramanian, K Premalatha, N A...
# 4  [M Rajangam, C Annamalai, M Rajangam, C Annama...
#
#                                             journals  \
# 0  [Academic Open Internet Journal 15, 2005, IETE...
# 1  [2010 IEEE International Conference on Computa...
# 2  [Procedia Computer Science 47, 255-261, 2015, ...
# 3  [International Journal of Bio-Inspired Computa...
# 4  [Cognitive Systems Research 56, 56-71, 2019, I...
#
#                                         article_link
# 0  [https://scholar.google.com/citations?view_op=...
# 1  [https://scholar.google.com/citations?view_op=...
# 2  [https://scholar.google.com/citations?view_op=...
# 3  [https://scholar.google.com/citations?view_op=...
# 4  [https://scholar.google.com/citations?view_op=...

# %%
df1.head(3)
# Out:
#                            name                                email  \
# 0              Geetha Ganapathi      Verified email at psgtech.ac.in
# 1          sai sundara Krishnan  Verified email at amc.psgtech.ac.in
# 2  Muthukrishnan, Senthil Kumar  Verified email at amc.psgtech.ac.in
#
#                                       website  \
# 0      http://psgtech.edu/facgen.php?id=C1631
# 1                                         NaN
# 2  http://www.psgtech.edu/facgen.php?id=C5457
#
#                                            interests  \
# 0  [{'title': 'Pattern Recognition', 'link': 'htt...
# 1  [{'title': 'OpeartionTopology', 'link': 'https...
# 2  [{'title': 'Retrial Queue', 'link': 'https://s...
#
#                                         affiliations  \
# 0             Professor, P S G College of Technology
# 1  Professor,Department of Applied Mathematics an...
# 2  Professor of Applied Mathematics and Computati...
#
#                                            thumbnail  \
# 0  https://scholar.google.com/citations/images/av...
# 1  https://scholar.googleusercontent.com/citation...
# 2  https://scholar.googleusercontent.com/citation...
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 18, 'since_2018': 10}},...
# 1  [{'citations': {'all': 475, 'since_2018': 288}...
# 2  [{'citations': {'all': 344, 'since_2018': 200}...
#
#                                       cited_by_graph  \
# 0  [{'year': 2014, 'citations': 2}, {'year': 2015...
# 1  [{'year': 2004, 'citations': 12}, {'year': 200...
# 2  [{'year': 2009, 'citations': 1}, {'year': 2010...
#
#                                   public_access_link  public_access_available  \
# 0                                                NaN                      NaN
# 1  https://scholar.google.com/citations?view_op=l...                      1.0
# 2                                                NaN                      NaN
#
#    public_access_not_available  \
# 0                          NaN
# 1                          0.0
# 2                          NaN
#
#                                           co_authors  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'name': 'Arumuganathan.R', 'link': 'https://...
#
#                                                 link  \
# 0  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 1  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
# 2  /content/drive/MyDrive/Sem8/NLP/nlp_hackathon_...
#
#                                        article_title  \
# 0  [A fuzzy hybrid framework for offline signatur...
# 1  [A similarity measure of intuitionistic fuzzy ...
# 2  [On the single server Batch Arrival Retrial Qu...
#
#                               article_published_year  \
# 0  [QbdPMtIAAAAJ:u5HHmVD_uO8C, QbdPMtIAAAAJ:u-x6o...
# 1  [j5RFpaQAAAAJ:hC7cP41nSMkC, j5RFpaQAAAAJ:u5HHm...
# 2  [sh3pjU8AAAAJ:d1gkVwhDpl0C, sh3pjU8AAAAJ:9yKSN...
#
#                                              authors  \
# 0  [G Ganapathi, R Nadarajan, G Ganapathi, N Reth...
# 1  [SSG Muthukumar P, GSS Krishnan, GSS Krishnan,...
# 2  [MS Kumar, R Arumuganathan, MS Kumar, R Arumug...
#
#                                             journals
# 0  [Pattern Recognition and Machine Intelligence:...
# 1  [Applied Soft Computing 41 (41(2016)), 148–156...
# 2  [Quality Technology and Quantitative Managemen...

# %%
df1.columns
# Out:
# Index(['name', 'email', 'website', 'interests', 'affiliations', 'thumbnail',
#        'cited_by_table', 'cited_by_graph', 'public_access_link',
#        'public_access_available', 'public_access_not_available', 'co_authors',
#        'link', 'article_title', 'article_published_year', 'authors',
#        'journals', 'article_link'],
#       dtype='object')

# %%
df1_new=df1[['name', 'interests','affiliations', 'cited_by_table', 'cited_by_graph', 'article_title', 'article_published_year', 'authors','journals', 'article_link']]
df1_new.head(3)
# Out:
#                 name                                          interests  \
# 0       R Venkatesan  [{'title': 'Data structures', 'link': 'https:/...
# 1  G Sudha Sadasivam  [{'title': 'Data Analytics', 'link': 'https://...
# 2     Jayashree L.S.  [{'title': 'Internet of Things', 'link': 'http...
#
#                                         affiliations  \
# 0  professor of computer science and engineering,...
# 1          Professor, CSE, PSG College of technology
# 2                          PSG College of Technology
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 787, 'since_2018': 438}...
# 1  [{'citations': {'all': 1120, 'since_2018': 533...
# 2  [{'citations': {'all': 507, 'since_2018': 363}...
#
#                                       cited_by_graph  \
# 0  [{'year': 2006, 'citations': 3}, {'year': 2007...
# 1  [{'year': 2009, 'citations': 6}, {'year': 2010...
# 2  [{'year': 2007, 'citations': 4}, {'year': 2008...
#
#                                        article_title  \
# 0  [A SURVEY ON AUTOMATIC TEST CASE GENERATION, A...
# 1  [Improved cost-based algorithm for task schedu...
# 2  [Mammographic image enhancement using indirect...
#
#                               article_published_year  \
# 0  [sox193AAAAAJ:qxL8FJ1GzNcC, sox193AAAAAJ:Wp0gI...
# 1  [1TCSp8sAAAAJ:RGFaLdJalmkC, 1TCSp8sAAAAJ:kzcrU...
# 2  [mmNPmLoAAAAJ:vV6vV6tmYwMC, mmNPmLoAAAAJ:35N4Q...
#
#                                              authors  \
# 0  [M Prasanna, SN Sivanandam, R Venkatesan, Sund...
# 1  [S Selvarani, GS Sadhasivam, R Jayarani, S Sad...
# 2  [K Akila, LS Jayashree, A Vasuki, Elpiniki I. ...
#
#                                             journals  \
# 0  [Academic Open Internet Journal 15, 2005, IETE...
# 1  [2010 IEEE International Conference on Computa...
# 2  [Procedia Computer Science 47, 255-261, 2015, ...
#
#                                         article_link
# 0  [https://scholar.google.com/citations?view_op=...
# 1  [https://scholar.google.com/citations?view_op=...
# 2  [https://scholar.google.com/citations?view_op=...

# %%
ast.literal_eval(df1_new['interests'][0])[0]['title']
# Out:
# 'Data structures'

# %%
def pre_process(i):
  try:
    i = ast.literal_eval(i)
    title = []
    for j in i:
      title.append(j['title'])
  except:
    title = []
  return title

# %%
df1_new['interests'] = df1_new['interests'].apply(lambda x: pre_process(x))
# Out:
# <ipython-input-26-8163cc3e7489>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new['interests'] = df1_new['interests'].apply(lambda x: pre_process(x))

# %%
df1_new['cited_by_table'][0]
# Out:
# "[{'citations': {'all': 787, 'since_2018': 438}}, {'h_index': {'all': 17, 'since_2018': 13}}, {'i10_index': {'all': 29, 'since_2018': 19}}]"

# %%
def pre_process_citation(i):
  try:
    i = ast.literal_eval(i)
    return i[0]['citations']
  except:
    return {}

# %%
df1_new['citations'] = df1_new['cited_by_table'].apply(lambda x: pre_process_citation(x))
# Out:
# <ipython-input-29-cd6aa9ad8338>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new['citations'] = df1_new['cited_by_table'].apply(lambda x: pre_process_citation(x))

# %%
def pre_process_h(i):
  try:
    i = ast.literal_eval(i)
    return i[1]['h_index']
  except:
    return {}

# %%
df1_new['h_index'] = df1_new['cited_by_table'].apply(lambda x: pre_process_h(x))
# Out:
# <ipython-input-31-5afc0ca5a95f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new['h_index'] = df1_new['cited_by_table'].apply(lambda x: pre_process_h(x))

# %%
df1_new['h_index']
# Out:
# 0     {'all': 17, 'since_2018': 13}
# 1     {'all': 16, 'since_2018': 13}
# 2      {'all': 10, 'since_2018': 8}
# 3       {'all': 7, 'since_2018': 6}
# 4       {'all': 1, 'since_2018': 1}
# 5       {'all': 6, 'since_2018': 5}
# 6       {'all': 7, 'since_2018': 5}
# 7       {'all': 6, 'since_2018': 5}
# 8       {'all': 2, 'since_2018': 1}
# 9       {'all': 3, 'since_2018': 2}
# 10      {'all': 5, 'since_2018': 4}
# 11      {'all': 2, 'since_2018': 2}
# 12      {'all': 1, 'since_2018': 1}
# 13      {'all': 5, 'since_2018': 5}
# 14      {'all': 2, 'since_2018': 2}
# 15      {'all': 8, 'since_2018': 6}
# 16      {'all': 3, 'since_2018': 1}
# 17      {'all': 2, 'since_2018': 2}
# Name: h_index, dtype: object

# %%
def pre_process_i10(i):
  try:
    i = ast.literal_eval(i)
    return i[2]['i10_index']
  except:
    return {}

# %%
df1_new['i10_index'] = df1_new['cited_by_table'].apply(lambda x: pre_process_i10(x))
# Out:
# <ipython-input-34-fd145d130c62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new['i10_index'] = df1_new['cited_by_table'].apply(lambda x: pre_process_i10(x))

# %%
df1_new['i10_index']
# Out:
# 0     {'all': 29, 'since_2018': 19}
# 1     {'all': 25, 'since_2018': 17}
# 2      {'all': 10, 'since_2018': 8}
# 3       {'all': 5, 'since_2018': 3}
# 4       {'all': 1, 'since_2018': 1}
# 5       {'all': 4, 'since_2018': 2}
# 6       {'all': 2, 'since_2018': 1}
# 7       {'all': 2, 'since_2018': 1}
# 8       {'all': 0, 'since_2018': 0}
# 9       {'all': 2, 'since_2018': 0}
# 10      {'all': 4, 'since_2018': 3}
# 11      {'all': 0, 'since_2018': 0}
# 12      {'all': 0, 'since_2018': 0}
# 13      {'all': 1, 'since_2018': 1}
# 14      {'all': 1, 'since_2018': 0}
# 15      {'all': 8, 'since_2018': 6}
# 16      {'all': 2, 'since_2018': 0}
# 17      {'all': 0, 'since_2018': 0}
# Name: i10_index, dtype: object

# %%
df1_new['authors'] = df1_new['authors'].apply(lambda x: set(x))
# Out:
# <ipython-input-36-4402ecd2ca66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new['authors'] = df1_new['authors'].apply(lambda x: set(x))

# %%
df1_new.head()
# Out:
#                 name                                          interests  \
# 0       R Venkatesan  [Data structures, Algorithm Design, Software E...
# 1  G Sudha Sadasivam                  [Data Analytics, Cloud Computing]
# 2     Jayashree L.S.  [Internet of Things, wireless sensor networks,...
# 3    Dr. N Arulanand           [Embedded Systems, IoT, Computer Vision]
# 4      Marx Rajangam  [Artificial Intelligence, Machine learning, Da...
#
#                                         affiliations  \
# 0  professor of computer science and engineering,...
# 1          Professor, CSE, PSG College of technology
# 2                          PSG College of Technology
# 3  Professor, Department of Computer Science and ...
# 4                          PSG College of Technology
#
#                                       cited_by_graph  \
# 0  [{'year': 2006, 'citations': 3}, {'year': 2007...
# 1  [{'year': 2009, 'citations': 6}, {'year': 2010...
# 2  [{'year': 2007, 'citations': 4}, {'year': 2008...
# 3  [{'year': 2012, 'citations': 3}, {'year': 2013...
# 4  [{'year': 2019, 'citations': 1}, {'year': 2020...
#
#                                        article_title  \
# 0  [A SURVEY ON AUTOMATIC TEST CASE GENERATION, A...
# 1  [Improved cost-based algorithm for task schedu...
# 2  [Mammographic image enhancement using indirect...
# 3  [A comparative study of cuckoo search and bat ...
# 4  [Extractive document summarization using an ad...
#
#                               article_published_year  \
# 0  [sox193AAAAAJ:qxL8FJ1GzNcC, sox193AAAAAJ:Wp0gI...
# 1  [1TCSp8sAAAAJ:RGFaLdJalmkC, 1TCSp8sAAAAJ:kzcrU...
# 2  [mmNPmLoAAAAJ:vV6vV6tmYwMC, mmNPmLoAAAAJ:35N4Q...
# 3  [cLqiFpwAAAAJ:LkGwnXOMwfcC, cLqiFpwAAAAJ:Y0pCk...
# 4  [l8aYEJcAAAAJ:u-x6o8ySG0sC, l8aYEJcAAAAJ:u5HHm...
#
#                                              authors  \
# 0  {IS AKILA, R VENKATESAN, R Venkatesan, MU Aham...
# 1  {S Sadasivam G, GS Sadasivam, KA Kumari, S Rub...
# 2  {C Padmavathy, LS Jayashree, PA Prabu, LS Jaya...
# 3  {NA K.Madhumitha, AR Babu, N Arulanand, VS Cha...
# 4                          {M Rajangam, C Annamalai}
#
#                                             journals  \
# 0  [Academic Open Internet Journal 15, 2005, IETE...
# 1  [2010 IEEE International Conference on Computa...
# 2  [Procedia Computer Science 47, 255-261, 2015, ...
# 3  [International Journal of Bio-Inspired Computa...
# 4  [Cognitive Systems Research 56, 56-71, 2019, I...
#
#                                         article_link  \
# 0  [https://scholar.google.com/citations?view_op=...
# 1  [https://scholar.google.com/citations?view_op=...
# 2  [https://scholar.google.com/citations?view_op=...
# 3  [https://scholar.google.com/citations?view_op=...
# 4  [https://scholar.google.com/citations?view_op=...
#
#                           citations                        h_index  \
# 0   {'all': 787, 'since_2018': 438}  {'all': 17, 'since_2018': 13}
# 1  {'all': 1120, 'since_2018': 533}  {'all': 16, 'since_2018': 13}
# 2   {'all': 507, 'since_2018': 363}   {'all': 10, 'since_2018': 8}
# 3    {'all': 154, 'since_2018': 87}    {'all': 7, 'since_2018': 6}
# 4     {'all': 12, 'since_2018': 12}    {'all': 1, 'since_2018': 1}
#
#                        i10_index
# 0  {'all': 29, 'since_2018': 19}
# 1  {'all': 25, 'since_2018': 17}
# 2   {'all': 10, 'since_2018': 8}
# 3    {'all': 5, 'since_2018': 3}
# 4    {'all': 1, 'since_2018': 1}

# %%
df1_new.drop(columns = ['cited_by_table'], inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1_new.to_csv('/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_cse/faculty_details_cse1.csv')

# %% [markdown]
# ## 2

# %%
df1_new = pd.read_csv('/content/drive/MyDrive/Sem8/NLP/nlp_hackathon_amcs/faculty_details_2.csv')

# %%
df1_new.head()
# Out:
#    Unnamed: 0                          name  \
# 0           0              Geetha Ganapathi
# 1           1          sai sundara Krishnan
# 2           2  Muthukrishnan, Senthil Kumar
# 3           3            MOHANRAJ NATARAJAN
# 4           4                   Shina Sheen
#
#                                            interests  \
# 0        ['Pattern Recognition', 'Machine Learning']
# 1  ['OpeartionTopology', 'Digital Topology and So...
# 2  ['Retrial Queue', 'Queueing Theory', 'Communic...
# 3  ['Software Engineering', 'OOAD', 'Agile Softwa...
# 4  ['Malware detection', 'Network security', 'Dat...
#
#                                         affiliations  \
# 0             Professor, P S G College of Technology
# 1  Professor,Department of Applied Mathematics an...
# 2  Professor of Applied Mathematics and Computati...
# 3                                Associate Professor
# 4  Associate Professor, PSG College of Technology...
#
#                                       cited_by_table  \
# 0  [{'citations': {'all': 18, 'since_2018': 10}},...
# 1  [{'citations': {'all': 475, 'since_2018': 288}...
# 2  [{'citations': {'all': 344, 'since_2018': 200}...
# 3  [{'citations': {'all': 1, 'since_2018': 0}}, {...
# 4  [{'citations': {'all': 299, 'since_2018': 187}...
#
#                                       cited_by_graph  \
# 0  [{'year': 2014, 'citations': 2}, {'year': 2015...
# 1  [{'year': 2004, 'citations': 12}, {'year': 200...
# 2  [{'year': 2009, 'citations': 1}, {'year': 2010...
# 3                                                NaN
# 4  [{'year': 2009, 'citations': 1}, {'year': 2010...
#
#                                        article_title  \
# 0  ['A fuzzy hybrid framework for offline signatu...
# 1  ['A similarity measure of intuitionistic fuzzy...
# 2  ['On the single server Batch Arrival Retrial Q...
# 3  ['Distributed Pair Programming: A Survey', 'In...
# 4  ['Android based malware detection using a mult...
#
#                               article_published_year  \
# 0  ['QbdPMtIAAAAJ:u5HHmVD_uO8C', 'QbdPMtIAAAAJ:u-...
# 1  ['j5RFpaQAAAAJ:hC7cP41nSMkC', 'j5RFpaQAAAAJ:u5...
# 2  ['sh3pjU8AAAAJ:d1gkVwhDpl0C', 'sh3pjU8AAAAJ:9y...
# 3  ['Ln8nvagAAAAJ:u-x6o8ySG0sC', 'Ln8nvagAAAAJ:d1...
# 4  ['d0ptyhgAAAAJ:qjMakFHDy7sC', 'd0ptyhgAAAAJ:u5...
#
#                                              authors  \
# 0  {'G Ganapathi, NV Kumar', 'G Ganapathi, N Reth...
# 1  {'R Parimelazhagan, N Nagaveni, S sundara Kris...
# 2  {'K Myilsamy, A Satheesh Kumar, SK Muthukrishn...
# 3  {'N Mohanraj, A Sankar, VS Kumaran', 'N Mohanr...
# 4  {'S Sheen, A Ramalingam', 'S Sheen, R Anitha, ...
#
#                                             journals  \
# 0  ['Pattern Recognition and Machine Intelligence...
# 1  ['Applied Soft Computing 41 (41(2016)), 148–15...
# 2  ['Quality Technology and Quantitative Manageme...
# 3  ['International Journal of Engineering Researc...
# 4  ['Neurocomputing 151, 905-912, 2015', 'TENCON ...
#
#                            citations                       h_index  \
# 0    [{'all': 18, 'since_2018': 10}]   {'all': 2, 'since_2018': 1}
# 1  [{'all': 475, 'since_2018': 288}]  {'all': 12, 'since_2018': 9}
# 2  [{'all': 344, 'since_2018': 200}]  {'all': 12, 'since_2018': 8}
# 3      [{'all': 1, 'since_2018': 0}]   {'all': 1, 'since_2018': 0}
# 4  [{'all': 299, 'since_2018': 187}]   {'all': 8, 'since_2018': 7}
#
#                       i10_index
# 0   {'all': 1, 'since_2018': 1}
# 1  {'all': 13, 'since_2018': 8}
# 2  {'all': 14, 'since_2018': 7}
# 3   {'all': 0, 'since_2018': 0}
# 4   {'all': 6, 'since_2018': 6}

# %%
df1_new['cited_by_graph'][0]
# Out:
# "[{'year': 2014, 'citations': 2}, {'year': 2015, 'citations': 1}, {'year': 2016, 'citations': 2}, {'year': 2017, 'citations': 1}, {'year': 2018, 'citations': 4}, {'year': 2019, 'citations': 2}, {'year': 2020, 'citations': 3}, {'year': 2021, 'citations': 1}]"
